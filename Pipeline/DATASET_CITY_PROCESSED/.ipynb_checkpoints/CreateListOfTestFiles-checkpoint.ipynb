# %% [markdown]
# #  TEST set files

# %%
import os
import sys
 
import csv

# %%
working_dir = os.getcwd()
print(working_dir)

parts = working_dir.split("/")
#if parts[-1] == "pipeline":
if parts[-1].startswith("pipeline"): ### BUG SOLVED MAY 2025
    pipeline = working_dir
else:
    pipeline ="/".join(parts[:-1])
print(pipeline)

base = pipeline
sys.path.append(base)

#-----------------------------------------------------------------------------------------
from config.configsite import * #basedir,inputdir

output_dir = f'{pipeline}/{dataset}_PROCESSED/'

 

os.makedirs(output_dir, exist_ok=True)

print(f"Output to {output_dir}")
# Out:
# /home/ematos/ateixeira/pipeline5/DATASET_SAUDE_PROCESSED
# /home/ematos/ateixeira/pipeline5
# Output to /home/ematos/ateixeira/pipeline5//DATASET_SAUDE_PROCESSED/

# %%
filename = "test_files_list.csv"

print(f"Saving to {output_dir+filename}")
# Out:
# Saving to /home/ematos/ateixeira/pipeline5//DATASET_SAUDE_PROCESSED/test_files_list.csv

# %%
def get_list_of_files(directory, pattern= "para"):  # pattern is only the start!!!
    print(f"List files {pattern} in {directory}")
    matches = []
    for root, dirs, files in os.walk(directory):
        for file in files:
            if file.startswith(pattern):
                matches.append(os.path.join(root, file))
    
    #print(matches)
    return matches

# %%
get_list_of_files(f'{pipeline}{dataset}/')
# Out:
# List files para in /home/ematos/ateixeira/pipeline5/DATASET_SAUDE/
# ['/home/ematos/ateixeira/pipeline5/DATASET_SAUDE/paragraph_006.txt',
#  '/home/ematos/ateixeira/pipeline5/DATASET_SAUDE/paragraph_010.txt',
#  '/home/ematos/ateixeira/pipeline5/DATASET_SAUDE/paragraph_001.txt',
#  '/home/ematos/ateixeira/pipeline5/DATASET_SAUDE/paragraph_009.txt',
#  '/home/ematos/ateixeira/pipeline5/DATASET_SAUDE/paragraph_003.txt',
#  '/home/ematos/ateixeira/pipeline5/DATASET_SAUDE/paragraph_012.txt',
#  '/home/ematos/ateixeira/pipeline5/DATASET_SAUDE/paragraph_011.txt',
#  '/home/ematos/ateixeira/pipeline5/DATASET_SAUDE/paragraph_008.txt',
#  '/home/ematos/ateixeira/pipeline5/DATASET_SAUDE/paragraph_005.txt',
#  '/home/ematos/ateixeira/pipeline5/DATASET_SAUDE/paragraph_004.txt',
#  '/home/ematos/ateixeira/pipeline5/DATASET_SAUDE/paragraph_002.txt',
#  '/home/ematos/ateixeira/pipeline5/DATASET_SAUDE/paragraph_007.txt']

# %%
def create_csv_for_files(directory, output_csv):
    # Get all filenames in the specified directory
    filenames = get_list_of_files(directory)  #os.listdir(directory)
    print(filenames[:3])
    
    # Create the CSV file
    with open(output_csv, 'w', encoding='utf-8', newline='') as csvfile:
        csv_writer = csv.writer(csvfile)
        
        # Write header row
        csv_writer.writerow(['filename', 'basename'])
        
        # Write each filename and a unique ID
        for idx, filename_complete in enumerate(filenames, start=1):

            parts = filename_complete.split("/")

            #print (parts)
            filename = parts[-1]  #+".txt"

            print(f"{filename}, {filename[:-4]}")
            csv_writer.writerow([filename, filename[:-4]])
    
    print(f"CSV file created: {output_csv} at {output_dir}")

# Example usage
create_csv_for_files(f'{pipeline}{dataset}/', filename)
# Out:
# List files para* in /home/ematos/ateixeira/pipeline5/DATASET_SAUDE/
# []
# CSV file created: test_files_list.csv at /home/ematos/ateixeira/pipeline5//DATASET_SAUDE_PROCESSED/
